# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("dataset/diabetes.csv")

profile = ProfileReport(df, title="Diabetes 데이터 분석")

profile.to_file("report/diabetes_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 45.48it/s]
